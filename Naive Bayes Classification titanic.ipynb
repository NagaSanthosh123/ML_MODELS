# %% [markdown]
# # NAIVE BAYES CLASSIFICATION

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=pd.read_csv('D:\\ML_MODELS\Book1.csv')
d
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
d.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
d.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)
d
# Out:
#      Pclass     Sex   Age     Fare  Survived
# 0         3    male  22.0   7.2500         0
# 1         1  female  38.0  71.2833         1
# 2         3  female  26.0   7.9250         1
# 3         1  female  35.0  53.1000         1
# 4         3    male  35.0   8.0500         0
# ..      ...     ...   ...      ...       ...
# 886       2    male  27.0  13.0000         0
# 887       1  female  19.0  30.0000         1
# 888       3  female   NaN  23.4500         0
# 889       1    male  26.0  30.0000         1
# 890       3    male  32.0   7.7500         0
#
# [891 rows x 5 columns]

# %%
d.head()
# Out:
#    Pclass     Sex   Age     Fare  Survived
# 0       3    male  22.0   7.2500         0
# 1       1  female  38.0  71.2833         1
# 2       3  female  26.0   7.9250         1
# 3       1  female  35.0  53.1000         1
# 4       3    male  35.0   8.0500         0

# %%
d
# Out:
#      Pclass        Age     Fare  female  male
# 0         3  22.000000   7.2500       0     1
# 1         1  38.000000  71.2833       1     0
# 2         3  26.000000   7.9250       1     0
# 3         1  35.000000  53.1000       1     0
# 4         3  35.000000   8.0500       0     1
# ..      ...        ...      ...     ...   ...
# 886       2  27.000000  13.0000       0     1
# 887       1  19.000000  30.0000       1     0
# 888       3  29.699118  23.4500       1     0
# 889       1  26.000000  30.0000       0     1
# 890       3  32.000000   7.7500       0     1
#
# [891 rows x 5 columns]

# %%
tar
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
d=d.drop(['Survived'],axis='columns')
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
# ----> 1 d=d.drop(['Survived'],axis='columns')
#       2 d
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
# ...

# %%
d1=pd.get_dummies(d.Sex)
d1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [79], in <cell line: 1>()
# ----> 1 d1=pd.get_dummies(d.Sex)
#       2 d1
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Sex'

# %%
d=d.drop(['Sex'],axis='columns')
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 d=d.drop(['Sex'],axis='columns')
#       2 d
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
d=pd.concat([d,d1],axis='columns')
d
# Out:
#      Pclass        Age     Fare  female  male  female  male
# 0         3  22.000000   7.2500       0     1       0     1
# 1         1  38.000000  71.2833       1     0       1     0
# 2         3  26.000000   7.9250       1     0       1     0
# 3         1  35.000000  53.1000       1     0       1     0
# 4         3  35.000000   8.0500       0     1       0     1
# ..      ...        ...      ...     ...   ...     ...   ...
# 886       2  27.000000  13.0000       0     1       0     1
# 887       1  19.000000  30.0000       1     0       1     0
# 888       3  29.699118  23.4500       1     0       1     0
# 889       1  26.000000  30.0000       0     1       0     1
# 890       3  32.000000   7.7500       0     1       0     1
#
# [891 rows x 7 columns]

# %%
d.columns[d.isna().any()]
# Out:
# Index([], dtype='object')

# %%
d.Age[:20]
# Out:
# 0     22.000000
# 1     38.000000
# 2     26.000000
# 3     35.000000
# 4     35.000000
# 5     29.699118
# 6     54.000000
# 7      2.000000
# 8     27.000000
# 9     14.000000
# 10     4.000000
# 11    58.000000
# 12    20.000000
# 13    39.000000
# 14    14.000000
# 15    55.000000
# 16     2.000000
# 17    29.699118
# 18    31.000000
# 19    29.699118
# Name: Age, dtype: float64

# %%
d.Age=d.Age.fillna(d.Age.mean())
d.Age[:20]
# Out:
# 0     22.000000
# 1     38.000000
# 2     26.000000
# 3     35.000000
# 4     35.000000
# 5     29.699118
# 6     54.000000
# 7      2.000000
# 8     27.000000
# 9     14.000000
# 10     4.000000
# 11    58.000000
# 12    20.000000
# 13    39.000000
# 14    14.000000
# 15    55.000000
# 16     2.000000
# 17    29.699118
# 18    31.000000
# 19    29.699118
# Name: Age, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(d,tar,test_size=0.2)

# %%
len(x_train),len(x_test),len(y_train),len(y_test)
# Out:
# (712, 179, 712, 179)

# %%
from sklearn.naive_bayes import GaussianNB
obj=GaussianNB()

# %%
obj
# Out:
# GaussianNB()

# %%
obj.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
obj.score(x_test,y_test)
# Out:
# 0.7877094972067039

# %%
obj.predict(x_test)[:10]
# Out:
# array([0, 1, 0, 0, 1, 1, 1, 0, 1, 0], dtype=int64)

# %%
y_test[:10]
# Out:
# 73     0
# 356    1
# 313    0
# 411    0
# 8      1
# 618    1
# 670    1
# 339    0
# 799    0
# 768    0
# Name: Survived, dtype: int64

# %%
obj.predict_proba(x_test)
# Out:
# array([[9.99306650e-01, 6.93350397e-04],
#        [6.55187565e-05, 9.99934481e-01],
#        [9.99308420e-01, 6.91579642e-04],
#        [9.99312150e-01, 6.87850192e-04],
#        [1.03395859e-03, 9.98966041e-01],
#        [1.89492748e-04, 9.99810507e-01],
#        [3.58915340e-04, 9.99641085e-01],
#        [9.92374405e-01, 7.62559493e-03],
#        [1.03103008e-03, 9.98968970e-01],
#        [9.99307579e-01, 6.92420761e-04],
#        [9.99295285e-01, 7.04714718e-04],
#        [9.94867176e-01, 5.13282428e-03],
#        [9.99266249e-01, 7.33751353e-04],
#        [3.54577798e-05, 9.99964542e-01],
#        [9.98411022e-01, 1.58897801e-03],
#        [1.00711417e-03, 9.98992886e-01],
#        [9.98303349e-01, 1.69665103e-03],
#        [1.04049043e-03, 9.98959510e-01],
#        [9.97971554e-01, 2.02844574e-03],
#        [9.99006947e-01, 9.93052533e-04],
#        [9.99313535e-01, 6.86465075e-04],
#        [9.99308288e-01, 6.91712253e-04],
#        [9.99248982e-01, 7.51018344e-04],
# ...
